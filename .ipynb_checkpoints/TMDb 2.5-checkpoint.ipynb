# %% [markdown]
# # Using the result obtained in previous question, find out if James McAvoy was credited for his role in movie Deadpool 2. Print Yes or No.

# %%
# First Fetch the id of person
import requests

r=requests.get("https://api.themoviedb.org/3/search/person",params={"api_key":"19601e45727396ac951a4ac501939657","query":"James McAvoy"})
r.status_code
# Out:
# 200

# %%
import json

p=json.loads(r.text)
ID=p["results"][0]["id"]
ID
# Out:
# 5530

# %%
rq=requests.get("https://api.themoviedb.org/3/person/5530/movie_credits",params={"api_key":"19601e45727396ac951a4ac501939657"})
rq.status_code
# Out:
# 200

# %%
pq=json.loads(rq.text)
pq
# Out:
# {'cast': [{'adult': False,
#    'backdrop_path': '/d4qvST6E66quWX6VVHolT2ccabx.jpg',
#    'genre_ids': [12, 16, 18, 14],
#    'id': 21290,
#    'original_language': 'en',
#    'original_title': 'Strings',
#    'overview': 'Strings is a mythological story about the son of a king, Hal Tara, who sets out on a journey to avenge the death of his father. To his surprise he discovers the truth of his own people - and where he least expects it - he finds true love.',
#    'popularity': 6.957,
#    'poster_path': '/lJJ5ePSlmx3BZ8jFPndboIA60iH.jpg',
#    'release_date': '2004-10-24',
#    'title': 'Strings',
#    'video': False,
#    'vote_average': 6.8,
#    'vote_count': 56,
#    'character': 'Hal (voice)',
#    'credit_id': '52fe4413c3a368484e00e095',
#    'order': 0},
#   {'adult': False,
#    'backdrop_path': '/ph1VSOvJ5JhDp7M4ozo3mAwNEyO.jpg',
#    'genre_ids': [18],
#    'id': 31165,
#    'original_language': 'en',
#    'original_title': "Inside I'm Dancing",
# ...

# %%
for i in pq["cast"]:
    if i["title"] == "Deadpool 2":
        print(i["character"])
# Out:
# Charles Xavier (uncredited)

# %%
# Answer


print("No")
# Out:
# No
