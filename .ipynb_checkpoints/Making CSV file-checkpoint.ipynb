# %%
import requests
import json

r=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=19601e45727396ac951a4ac501939657")
r.status_code
# Out:
# 401

# %%
p=json.loads(r.text)
p
# Out:
# {'page': 500,
#  'results': [{'adult': False,
#    'backdrop_path': '/4dlEX4GYbU1yskshllPE67pHlG0.jpg',
#    'genre_ids': [35, 14, 878],
#    'id': 56715,
#    'original_language': 'en',
#    'original_title': 'Just Visiting',
#    'overview': 'A knight and his valet are plagued by a witch, and to repair the damage they make use of the services of a wizard. However, something goes wrong and they are transported from the 12th century to the year 2000. There the knight meets some of his family and slowly learns what this new century is like. However, he still needs to get back to the 12th century to deal with the witch, so he starts looking for a wizard. Remake of  1993 French film Les Visiteurs (The Visitors).',
#    'popularity': 10.134,
#    'poster_path': '/7KqzbefXjADSUE8j2ZsrudvAArY.jpg',
#    'release_date': '2001-04-06',
#    'title': 'Just Visiting',
#    'video': False,
#    'vote_average': 4.6,
#    'vote_count': 546},
#   {'adult': False,
# ...

# %%
import pandas as pd
df
for i in range(1,501):
    r=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=19601e45727396ac951a4ac501939657&page={}".format(i))
    temp_df=pd.DataFrame(p["results"])
    df=df.append(temp_df,ignore_index=True)

# %%
df
# Out:
#        adult                     backdrop_path              genre_ids      id  \
# 0      False  /4dlEX4GYbU1yskshllPE67pHlG0.jpg          [35, 14, 878]   56715
# 1      False  /22qysYEwRuULLU9Ep8IkxPFOUnR.jpg                   [27]   79316
# 2      False  /xZy63KVyeQy2U2GGq2KtKSBTIta.jpg                   [27]  298584
# 3      False  /gUebSn2HgWchRx2sUwYAXpbxCfV.jpg     [27, 18, 53, 9648]  420707
# 4      False  /xmBJ9nezUteqowdYfrW8383LHd9.jpg              [53, 878]  248504
# ...      ...                               ...                    ...     ...
# 10015  False  /nB8WhH6VPvHiXngfEn7kSBdfSr2.jpg  [28, 12, 53, 18, 878]   11667
# 10016  False  /d9XffDhi65UsJhbHlu534l9P2cN.jpg               [53, 18]  109729
# 10017  False  /nluuHepuNveIYybe1injsScDb3N.jpg       [80, 28, 27, 53]   12095
# 10018  False  /oIClM946YzrDDNdhV4E6f0Z9nbx.jpg                   [35]   87818
# 10019  False  /2ixS8cjAwXBpIEotWAEsa5SbZ59.jpg               [35, 80]   11546
#
# ...

# %%
df.shape
# Out:
# (10020, 14)

# %%
df.to_csv("movies.csv")
